# %%
from sodapy import Socrata
import pandas as pd
import numpy as np
import streamlit as st

# %%
client = Socrata("healthdata.gov",
                 "siH9CVWI60z5Knc99NEfhUFss",
                 username= "alimusac@gmail.com",
                 password= "Alicemus4")
results = client.get("g62h-syeh", limit=50000)
datosCOVID = pd.DataFrame.from_records(results)

# %%
dfCOVID = datosCOVID.rename(columns={'state':'Estado', 'date':'Fecha', 'critical_staffing_shortage_today_yes':'Escasez de personal',
'critical_staffing_shortage_today_no':'No hay escasez de personal', 
'critical_staffing_shortage_today_not_reported':'No se reportó escasez de personal',
'hospital_onset_covid': 'Inicio de Covid en el hospital',
'hospital_onset_covid_coverage':'Cobertura del inicio de Covid en el hospital', 'inpatient_beds': 'Camas de hospitalización',
'inpatient_beds_coverage':'Cobertura de camas de hospitalización', 'inpatient_beds_used':'Camas de hospitalización usadas',
'inpatient_beds_used_coverage':'Cobertura de camas de hospitalización usadas', 
'inpatient_beds_used_covid':'Camas de hospitalización usadas por casos de Covid',
'inpatient_beds_used_covid_coverage':'Cobertura de camas de hospitalización usadas por casos de Covid',
'staffed_adult_icu_bed_occupancy':'Ocupación de camas de UCI para adultos con personal',
'staffed_adult_icu_bed_occupancy_coverage':'Cobertura de la ocupación de camas de UCI para adultos con personal',
'staffed_icu_adult_patients_confirmed_and_suspected_covid':'Pacientes de UCI adultos sospechados y confirmados de Covid con personal',
'staffed_icu_adult_patients_confirmed_and_suspected_covid_coverage':'Cobertura de pacientes de UCI adultos sospechados y confirmados de Covid con personal',
'staffed_icu_adult_patients_confirmed_covid':'Pacientes de UCI adultos confirmados de Covid con personal',
'staffed_icu_adult_patients_confirmed_covid_coverage':'Cobertura de pacientes de UCI adultos confirmados de Covid con personal',
'total_adult_patients_hospitalized_confirmed_and_suspected_covid':'Total de pacientes adultos hospitalizados sospechados y confirmados de Covid',
'total_adult_patients_hospitalized_confirmed_and_suspected_covid_coverage':'Cobertura del total de pacientes adultos hospitalizados sospechados y confirmados de Covid',
'total_adult_patients_hospitalized_confirmed_covid':'Total de pacientes adultos hospitalizados confirmados de Covid',
'total_adult_patients_hospitalized_confirmed_covid_coverage':'Cobertura del total de pacientes adultos hospitalizados y confirmados de Covid',
'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid':'Total de pacientes pediátricos hospitalizados sospechados y confirmados de Covid',
'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_coverage':'Cobertura del total de pacientes pediátricos hospitalizados sospechados y confirmados de Covid',
'total_pediatric_patients_hospitalized_confirmed_covid':'Total de pacientes pediátricos hospitalizados confirmados de Covid',
'total_pediatric_patients_hospitalized_confirmed_covid_coverage':'Cobertura del total de pacientes pediátricos hospitalizados confirmados de Covid',
'total_staffed_adult_icu_beds':'Total de camas de UCI para adultos con personal',
'total_staffed_adult_icu_beds_coverage':'Cobertura del total de camas de UCI para adultos con personal',
'inpatient_beds_utilization':'Utilización de camas de hospitalización',
'inpatient_beds_utilization_coverage':'Cobertura de la utilización de camas de hospitalización',
'percent_of_inpatients_with_covid':'Porcentaje de pacientes hospitalizados con covid',
'percent_of_inpatients_with_covid_coverage':'Cobertura del porcentaje de pacientes hospitalizados con covid',
'inpatient_bed_covid_utilization':'Utilización de camas de hospitalización por Covid',
'inpatient_bed_covid_utilization_coverage':'Cobertura de la utilización de camas de hospitalización por Covid',
'adult_icu_bed_covid_utilization':'Utilización de las camas de UCI para pacientes adultos con Covid',
'adult_icu_bed_covid_utilization_coverage':'Cobertura de la utilización de las camas de UCI para pacientes adultos con Covid',
'adult_icu_bed_utilization':'Utilización de las camas de UCI para pacientes adultos',
'adult_icu_bed_utilization_coverage':'Cobertura de la utilización de las camas de UCI para pacientes adultos',
'deaths_covid':'Muertes por Covid', 'deaths_covid_coverage':'Cobertura de muertes por Covid',
'all_pediatric_inpatient_bed_occupied':'Ocupación de las camas de hospitalización pediátrica',
'all_pediatric_inpatient_bed_occupied_coverage':'Cobertura de la ocupación de las camas de hospitalización pediátrica',
'all_pediatric_inpatient_beds':'Cantidad total de camas de hospitalización pediátrica',
'all_pediatric_inpatient_beds_coverage':'Cobertura de la cantidad total de camas de hospitalización pediátrica',
'staffed_icu_pediatric_patients_confirmed_covid':'Pacientes pediátricos de la UCI confirmados covid con personal',
'staffed_icu_pediatric_patients_confirmed_covid_coverage':'Cobertura de Pacientes pediátricos de la UCI confirmados covid con personal',
'staffed_pediatric_icu_bed_occupancy':'Ocupación de camas en la UCI pediátrica con personal',
'staffed_pediatric_icu_bed_occupancy_coverage':'Cobertura de ocupación de camas en la UCI pediátrica con personal',
'total_staffed_pediatric_icu_beds':'Total de camas de UCI pediátricos con personal',
'total_staffed_pediatric_icu_beds_coverage':'Cobertura del total de camas de UCI pediátricos con personal'})

# %%
dfCOVID1 = dfCOVID.drop(columns=['critical_staffing_shortage_anticipated_within_week_no', 
'critical_staffing_shortage_anticipated_within_week_yes', 'previous_day_admission_adult_covid_confirmed', 
'critical_staffing_shortage_anticipated_within_week_not_reported',
'previous_day_admission_adult_covid_confirmed_coverage', 'previous_day_admission_adult_covid_suspected', 
'previous_day_admission_adult_covid_suspected_coverage', 'previous_day_admission_pediatric_covid_confirmed',
'previous_day_admission_pediatric_covid_confirmed_coverage', 'previous_day_admission_pediatric_covid_suspected',
'previous_day_admission_pediatric_covid_suspected_coverage', 'inpatient_beds_utilization_numerator'])

# %%
dfCOVID2 = dfCOVID1.drop(columns=['inpatient_beds_utilization_denominator', 'percent_of_inpatients_with_covid_numerator', 'percent_of_inpatients_with_covid_denominator',
'inpatient_bed_covid_utilization_numerator','inpatient_bed_covid_utilization_denominator','adult_icu_bed_covid_utilization_numerator',
'adult_icu_bed_covid_utilization_denominator','adult_icu_bed_utilization_numerator','adult_icu_bed_utilization_denominator'])

# %%
dfCOVID3 = dfCOVID2.drop(columns=['previous_day_admission_adult_covid_confirmed_unknown','previous_day_admission_adult_covid_confirmed_unknown_coverage'])

# %%
dfCOVID4 = dfCOVID3.drop(columns=['previous_day_admission_adult_covid_suspected_unknown','previous_day_admission_adult_covid_suspected_unknown_coverage',
'on_hand_supply_therapeutic_a_casirivimab_imdevimab_courses','on_hand_supply_therapeutic_b_bamlanivimab_courses',
'on_hand_supply_therapeutic_c_bamlanivimab_etesevimab_courses','previous_week_therapeutic_a_casirivimab_imdevimab_courses_used',
'previous_week_therapeutic_b_bamlanivimab_courses_used','previous_week_therapeutic_c_bamlanivimab_etesevimab_courses_used',
'icu_patients_confirmed_influenza','icu_patients_confirmed_influenza_coverage','previous_day_admission_influenza_confirmed'])

# %%
dfCOVID5 = dfCOVID4.drop(columns=['previous_day_admission_influenza_confirmed_coverage','previous_day_deaths_covid_and_influenza',
'previous_day_deaths_covid_and_influenza_coverage','previous_day_deaths_influenza','previous_day_deaths_influenza_coverage',
'total_patients_hospitalized_confirmed_influenza','total_patients_hospitalized_confirmed_influenza_and_covid',
'total_patients_hospitalized_confirmed_influenza_and_covid_coverage','total_patients_hospitalized_confirmed_influenza_coverage'])

# %%
dfCOVID6 = dfCOVID5.drop(columns=['previous_day_admission_pediatric_covid_confirmed_0_4','previous_day_admission_pediatric_covid_confirmed_0_4_coverage',
'previous_day_admission_pediatric_covid_confirmed_12_17','previous_day_admission_pediatric_covid_confirmed_12_17_coverage',
'previous_day_admission_pediatric_covid_confirmed_5_11','previous_day_admission_pediatric_covid_confirmed_5_11_coverage',
'previous_day_admission_pediatric_covid_confirmed_unknown','previous_day_admission_pediatric_covid_confirmed_unknown_coverage'])

# %%
print(dfCOVID6.columns.tolist())
# Out:
# ['Estado', 'Fecha', 'Escasez de personal', 'No hay escasez de personal', 'No se reportó escasez de personal', 'Inicio de Covid en el hospital', 'Cobertura del inicio de Covid en el hospital', 'Camas de hospitalización', 'Cobertura de camas de hospitalización', 'Camas de hospitalización usadas', 'Cobertura de camas de hospitalización usadas', 'Camas de hospitalización usadas por casos de Covid', 'Cobertura de camas de hospitalización usadas por casos de Covid', 'Ocupación de camas de UCI para adultos con personal', 'Cobertura de la ocupación de camas de UCI para adultos con personal', 'Pacientes de UCI adultos sospechados y confirmados de Covid con personal', 'Cobertura de pacientes de UCI adultos sospechados y confirmados de Covid con personal', 'Pacientes de UCI adultos confirmados de Covid con personal', 'Cobertura de pacientes de UCI adultos confirmados de Covid con personal', 'Total de pacientes adultos hospitalizados sospechados y confirmados de Covid', 'Cobertura del total de p
# ...

# %%
dfCOVID7 = dfCOVID6.drop(columns=['previous_day_admission_adult_covid_confirmed_18_19', 
'previous_day_admission_adult_covid_confirmed_18_19_coverage', 'previous_day_admission_adult_covid_confirmed_20_29', 
'previous_day_admission_adult_covid_confirmed_20_29_coverage', 'previous_day_admission_adult_covid_confirmed_30_39', 
'previous_day_admission_adult_covid_confirmed_30_39_coverage', 'previous_day_admission_adult_covid_confirmed_40_49', 
'previous_day_admission_adult_covid_confirmed_40_49_coverage'])

# %%
dfCOVID8 = dfCOVID7.drop(columns=['previous_day_admission_adult_covid_confirmed_50_59', 
'previous_day_admission_adult_covid_confirmed_50_59_coverage', 'previous_day_admission_adult_covid_confirmed_60_69', 
'previous_day_admission_adult_covid_confirmed_60_69_coverage', 'previous_day_admission_adult_covid_confirmed_70_79', 
'previous_day_admission_adult_covid_confirmed_70_79_coverage'])

# %%
dfCOVID9 = dfCOVID8.drop(columns=['previous_day_admission_adult_covid_confirmed_80', 
'previous_day_admission_adult_covid_confirmed_80_coverage', 'previous_day_admission_adult_covid_suspected_18_19', 
'previous_day_admission_adult_covid_suspected_18_19_coverage', 'previous_day_admission_adult_covid_suspected_20_29', 
'previous_day_admission_adult_covid_suspected_20_29_coverage'])

# %%
dfCOVID10 = dfCOVID9.drop(columns=['previous_day_admission_adult_covid_suspected_30_39', 
'previous_day_admission_adult_covid_suspected_30_39_coverage', 'previous_day_admission_adult_covid_suspected_40_49', 
'previous_day_admission_adult_covid_suspected_40_49_coverage', 'previous_day_admission_adult_covid_suspected_50_59', 
'previous_day_admission_adult_covid_suspected_50_59_coverage'])

# %%
dfCOVID11 = dfCOVID10.drop(columns=['previous_day_admission_adult_covid_suspected_60_69', 
'previous_day_admission_adult_covid_suspected_60_69_coverage', 'previous_day_admission_adult_covid_suspected_70_79', 
'previous_day_admission_adult_covid_suspected_70_79_coverage', 'previous_day_admission_adult_covid_suspected_80_', 
'previous_day_admission_adult_covid_suspected_80_coverage'])

# %%
dfCOVID11
# Out:
#       Estado                    Fecha Escasez de personal  \
# 0         PR  2020-12-23T00:00:00.000                  11
# 1         OR  2020-12-22T00:00:00.000                   5
# 2         VI  2020-10-16T00:00:00.000                   1
# 3         VI  2020-10-15T00:00:00.000                   1
# 4         PR  2020-10-14T00:00:00.000                   9
# ...      ...                      ...                 ...
# 47796     AS  2022-02-17T00:00:00.000                   0
# 47797     CA  2022-02-05T00:00:00.000                  14
# 47798     NM  2022-02-20T00:00:00.000                   2
# 47799     ND  2022-02-03T00:00:00.000                   0
# 47800     RI  2022-02-04T00:00:00.000                   1
#
#       No hay escasez de personal No se reportó escasez de personal  \
# 0                             51                                 5
# 1                             55                                 2
# ...

# %%
import datetime as dt
def FormatoFecha(columna_fecha):
    columna_fecha = pd.to_datetime(columna_fecha)
    return columna_fecha

# %%
dfCOVID11['Fecha'] = FormatoFecha(dfCOVID11['Fecha'])

# %%
dfCOVID11.dtypes
# Out:
# Estado                                                                                                    object
# Fecha                                                                                             datetime64[ns]
# Escasez de personal                                                                                       object
# No hay escasez de personal                                                                                object
# No se reportó escasez de personal                                                                         object
# Inicio de Covid en el hospital                                                                            object
# Cobertura del inicio de Covid en el hospital                                                              object
# Camas de hospitalización                                                                                  object
# ...

# %%
dfCOVIDf = dfCOVID11[(dfCOVID11['Fecha'])<='2022-08-01']
dfCOVIDf.sort_values(by= 'Fecha', ascending= False).head()
# Out:
#       Estado      Fecha Escasez de personal No hay escasez de personal  \
# 42501     VI 2022-08-01                   0                          2
# 42855     AL 2022-08-01                   0                          8
# 37377     RI 2022-08-01                   1                          0
# 42514     MD 2022-08-01                   3                         32
# 34461     PR 2022-08-01                   0                         16
#
#       No se reportó escasez de personal Inicio de Covid en el hospital  \
# 42501                                 0                              0
# 42855                               104                             39
# 37377                                13                              2
# 42514                                18                             26
# 34461                                49                              6
#
#       Cobertura del inicio de Covid en el hospital Camas de hospitalización  \
# ...
